# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('/Users/mithunkumar/Documents/PhD/COVID Research/COVIDE/chest_xray/test/NORMAL/IM-0001-0001.jpeg',0)

# Initiate STAR detector
orb = cv2.ORB()

# find the keypoints with ORB
kp = orb.detect(img,None)

# compute the descriptors with ORB
kp, des = orb.compute(img, kp)

# draw only keypoints location,not size and orientation
img2 = cv2.drawKeypoints(img,kp,color=(0,255,0), flags=0)
plt.imshow(img2),plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
img = cv2.imread('/Users/mithunkumar/Documents/PhD/COVID Research/COVIDE/chest_xray/test/NORMAL/IM-0001-0001.jpeg',0)
img
# Out:
# array([[ 0, 32, 33, ..., 33, 34,  0],
#        [ 0, 33, 33, ..., 34, 34,  0],
#        [ 1, 33, 33, ..., 34, 34,  0],
#        ...,
#        [ 0, 28, 28, ..., 34, 35,  0],
#        [ 0, 29, 28, ..., 34, 35,  0],
#        [ 0, 29, 29, ..., 35, 34,  0]], dtype=uint8)

# %%
# Initiate STAR detector
orb = cv2.ORB()

# %%
# find the keypoints with ORB
kp = orb.detect(img,None)

# %%
# compute the descriptors with ORB
kp, des = orb.compute(img, kp)

# draw only keypoints location,not size and orientation
img2 = cv2.drawKeypoints(img,kp,color=(0,255,0), flags=0)
plt.imshow(img2),plt.show()

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

img = cv2.imread('/Users/mithunkumar/Documents/PhD/COVID Research/COVIDE/chest_xray/test/NORMAL/IM-0001-0001.jpeg',0)

# Initiate STAR detector
star = cv2.FeatureDetector_create("STAR")

# Initiate BRIEF extractor
brief = cv2.DescriptorExtractor_create("BRIEF")

# find the keypoints with STAR
kp = star.detect(img,None)

# compute the descriptors with BRIEF
kp, des = brief.compute(img, kp)

print brief.getInt('bytes')
print des.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-1cca3a8525de> in <module>()
#       6
#       7 # Initiate STAR detector
# ----> 8 star = cv2.FeatureDetector_create("STAR")
#       9
#      10 # Initiate BRIEF extractor
#
# AttributeError: 'module' object has no attribute 'FeatureDetector_create'

# %%
import cv2
import numpy as np

img = cv2.imread('/Users/mithunkumar/Documents/PhD/COVID Research/COVIDE/chest_xray/test/NORMAL/IM-0001-0001.jpeg')
gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

sift = cv2.SIFT()
kp = sift.detect(gray,None)

img=cv2.drawKeypoints(gray,kp)

cv2.imwrite('sift_keypoints.jpg',img)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-2c87dd48b842> in <module>()
#       5 gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       6
# ----> 7 sift = cv2.SIFT()
#       8 kp = sift.detect(gray,None)
#       9
#
# AttributeError: 'module' object has no attribute 'SIFT'

# %%
import matplotlib.pyplot as plt

from skimage.feature import greycomatrix, greycoprops
from skimage import data
import cv2

PATCH_SIZE = 21

# open the camera image
# image = data.camera()
image = cv2.imread('/Users/mithunkumar/Documents/PhD/COVID Research/COVIDE/chest_xray/test/NORMAL/IM-0001-0001.jpeg')

im = cv2.imread(train_image)
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
ngcm= greycomatrix(im, [1], [0], 256, symmetric=False, normed=True)

# select some patches from grassy areas of the image
grass_locations = [(474, 291), (440, 433), (466, 18), (462, 236)]
grass_patches = []
for loc in grass_locations:
    grass_patches.append(image[loc[0]:loc[0] + PATCH_SIZE,
                               loc[1]:loc[1] + PATCH_SIZE])

# select some patches from sky areas of the image
sky_locations = [(54, 48), (21, 233), (90, 380), (195, 330)]
sky_patches = []
for loc in sky_locations:
    sky_patches.append(image[loc[0]:loc[0] + PATCH_SIZE,
                             loc[1]:loc[1] + PATCH_SIZE])

# compute some GLCM properties each patch
xs = []
ys = []
for patch in (grass_patches + sky_patches):
    glcm = greycomatrix(patch, distances=[5], angles=[0], levels=256,
                        symmetric=True, normed=True)
    xs.append(greycoprops(glcm, 'dissimilarity')[0, 0])
    ys.append(greycoprops(glcm, 'correlation')[0, 0])

# create the figure
fig = plt.figure(figsize=(8, 8))

# display original image with locations of patches
ax = fig.add_subplot(3, 2, 1)
ax.imshow(image, cmap=plt.cm.gray,
          vmin=0, vmax=255)
for (y, x) in grass_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'gs')
for (y, x) in sky_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'bs')
ax.set_xlabel('Original Image')
ax.set_xticks([])
ax.set_yticks([])
ax.axis('image')

# for each patch, plot (dissimilarity, correlation)
ax = fig.add_subplot(3, 2, 2)
ax.plot(xs[:len(grass_patches)], ys[:len(grass_patches)], 'go',
        label='Grass')
ax.plot(xs[len(grass_patches):], ys[len(grass_patches):], 'bo',
        label='Sky')
ax.set_xlabel('GLCM Dissimilarity')
ax.set_ylabel('GLCM Correlation')
ax.legend()

# display the image patches
for i, patch in enumerate(grass_patches):
    ax = fig.add_subplot(3, len(grass_patches), len(grass_patches)*1 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray,
              vmin=0, vmax=255)
    ax.set_xlabel('Grass %d' % (i + 1))

for i, patch in enumerate(sky_patches):
    ax = fig.add_subplot(3, len(sky_patches), len(sky_patches)*2 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray,
              vmin=0, vmax=255)
    ax.set_xlabel('Sky %d' % (i + 1))


# display the patches and plot
fig.suptitle('Grey level co-occurrence matrix features', fontsize=14, y=1.05)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-1994c6297197> in <module>()
#      30 for patch in (grass_patches + sky_patches):
#      31     glcm = greycomatrix(patch, distances=[5], angles=[0], levels=256,
# ---> 32                         symmetric=True, normed=True)
#      33     xs.append(greycoprops(glcm, 'dissimilarity')[0, 0])
#      34     ys.append(greycoprops(glcm, 'correlation')[0, 0])
#
# /opt/anaconda2/lib/python2.7/site-packages/skimage/feature/texture.pyc in greycomatrix(image, distances, angles, levels, symmetric, normed)
#      99
#     100     """
# --> 101     assert_nD(image, 2)
#     102     assert_nD(distances, 1, 'distances')
#     103     assert_nD(angles, 1, 'angles')
#
# /opt/anaconda2/lib/python2.7/site-packages/skimage/_shared/utils.pyc in assert_nD(array, ndim, arg_name)
# ...

# %%
import matplotlib.pyplot as plt

from skimage.feature import greycomatrix, greycoprops
from skimage import data
import cv2

PATCH_SIZE = 21

# open the camera image
# image = data.camera()
im = cv2.imread('/Users/mithunkumar/Documents/PhD/COVID Research/COVIDE/chest_xray/test/NORMAL/IM-0001-0001.jpeg')
im = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
image= greycomatrix(im, [1], [0], 256, symmetric=False, normed=True)
image
# Out:
# array([[[[4.09106381e-07]],
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00]],
#
#         [[4.09106381e-07]],
#
#         [[8.18212762e-07]]],
#
#
#        [[[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]]],
#
#
#        [[[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         ...,
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         [[4.09106381e-07]]],
#
#
#        ...,
#
#
#        [[[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         ...,
#
#         [[1.22731914e-05]],
#
#         [[5.31838295e-06]],
#
#         [[1.88188935e-05]]],
#
#
#        [[[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         [[0.00000000e+00]],
#
#         ...,
#
# ...

# %%
# select some patches from grassy areas of the image
grass_locations = [(474, 291), (440, 433), (466, 18), (462, 236)]
grass_patches = []
for loc in grass_locations:
    grass_patches.append(image[loc[0]:loc[0] + PATCH_SIZE,
                               loc[1]:loc[1] + PATCH_SIZE])

# select some patches from sky areas of the image
sky_locations = [(54, 48), (21, 233), (90, 380), (195, 330)]
sky_patches = []
for loc in sky_locations:
    sky_patches.append(image[loc[0]:loc[0] + PATCH_SIZE,
                             loc[1]:loc[1] + PATCH_SIZE])

# compute some GLCM properties each patch
xs = []
ys = []
for patch in (grass_patches + sky_patches):
    glcm = greycomatrix(patch, distances=[5], angles=[0], levels=256,
                        symmetric=True, normed=True)
    xs.append(greycoprops(glcm, 'dissimilarity')[0, 0])
    ys.append(greycoprops(glcm, 'correlation')[0, 0])

# create the figure
fig = plt.figure(figsize=(8, 8))

# display original image with locations of patches
ax = fig.add_subplot(3, 2, 1)
ax.imshow(image, cmap=plt.cm.gray,
          vmin=0, vmax=255)
for (y, x) in grass_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'gs')
for (y, x) in sky_locations:
    ax.plot(x + PATCH_SIZE / 2, y + PATCH_SIZE / 2, 'bs')
ax.set_xlabel('Original Image')
ax.set_xticks([])
ax.set_yticks([])
ax.axis('image')

# for each patch, plot (dissimilarity, correlation)
ax = fig.add_subplot(3, 2, 2)
ax.plot(xs[:len(grass_patches)], ys[:len(grass_patches)], 'go',
        label='Grass')
ax.plot(xs[len(grass_patches):], ys[len(grass_patches):], 'bo',
        label='Sky')
ax.set_xlabel('GLCM Dissimilarity')
ax.set_ylabel('GLCM Correlation')
ax.legend()

# display the image patches
for i, patch in enumerate(grass_patches):
    ax = fig.add_subplot(3, len(grass_patches), len(grass_patches)*1 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray,
              vmin=0, vmax=255)
    ax.set_xlabel('Grass %d' % (i + 1))

for i, patch in enumerate(sky_patches):
    ax = fig.add_subplot(3, len(sky_patches), len(sky_patches)*2 + i + 1)
    ax.imshow(patch, cmap=plt.cm.gray,
              vmin=0, vmax=255)
    ax.set_xlabel('Sky %d' % (i + 1))


# display the patches and plot
fig.suptitle('Grey level co-occurrence matrix features', fontsize=14, y=1.05)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-f6848893783b> in <module>()
#      19 for patch in (grass_patches + sky_patches):
#      20     glcm = greycomatrix(patch, distances=[5], angles=[0], levels=256,
# ---> 21                         symmetric=True, normed=True)
#      22     xs.append(greycoprops(glcm, 'dissimilarity')[0, 0])
#      23     ys.append(greycoprops(glcm, 'correlation')[0, 0])
#
# /opt/anaconda2/lib/python2.7/site-packages/skimage/feature/texture.pyc in greycomatrix(image, distances, angles, levels, symmetric, normed)
#      99
#     100     """
# --> 101     assert_nD(image, 2)
#     102     assert_nD(distances, 1, 'distances')
#     103     assert_nD(angles, 1, 'angles')
#
# /opt/anaconda2/lib/python2.7/site-packages/skimage/_shared/utils.pyc in assert_nD(array, ndim, arg_name)
#     174         ndim = [ndim]
# ...
